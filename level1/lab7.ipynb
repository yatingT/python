# %%
PI = "three, dot, one, four, one, five, nine, two, six, five, three, five, nine"
counts = {}
for char in PI:
    if not char in counts:
        counts[char] = 1 
    else:
        counts[char] += 1
counts
# Out:
# {'t': 4,
#  'h': 2,
#  'r': 3,
#  'e': 11,
#  ',': 12,
#  ' ': 12,
#  'd': 1,
#  'o': 5,
#  'n': 6,
#  'f': 4,
#  'u': 1,
#  'i': 6,
#  'v': 3,
#  'w': 1,
#  's': 1,
#  'x': 1}

# %%
PI = "three, dot, one, four, one, five, nine, two, six, five, three, five, nine"
counts = {}
for word in PI.split(", "):
    if not word in counts:
        counts[word] = 1 
    else:
        counts[word] += 1

counts
# Out:
# {'three': 2,
#  'dot': 1,
#  'one': 2,
#  'four': 1,
#  'five': 3,
#  'nine': 2,
#  'two': 1,
#  'six': 1}

# %%
keys = ["three", "zero", "one"]
vals = ["tres", "cero", "uno"]
en2sp = {} # empty dictionary
for i in range(len(keys)):
    en2sp[keys[i]] = vals[i]
en2sp
# Out:
# {'three': 'tres', 'zero': 'cero', 'one': 'uno'}

# %%
words = "I love Comp Sci three zero one".split(" ")
for i in range(len(words)):
    default = words[i] # don't translate it
    words[i] = en2sp.get(words[i], default)
" ".join(words)
# Out:
# 'I love Comp Sci tres cero uno'

# %%
sp2en = {}
for en in en2sp:
    sp = en2sp[en]
    sp2en[sp] = en
sp2en
# Out:
# {'tres': 'three', 'cero': 'zero', 'uno': 'one'}

# %%
numerators = {"A": 1, "B": 2, "C": 3}
denominators = {"A": 2, "B": 4, "C": 4}
result = {}
for key in numerators:
    result[key] = numerators[key] / denominators[key]
result
# Out:
# {'A': 0.5, 'B': 0.5, 'C': 0.75}

# %%
incidents = {2016: 14, 2019: 18, 2017: 13, 2018: 16, 2014: 8, 2015: 10}
keys = sorted(list(incidents.keys()))
for k in keys:
    print(k, "*" * incidents[k])
# Out:
# 2014 ********
# 2015 **********
# 2016 **************
# 2017 *************
# 2018 ****************
# 2019 ******************

# %%
incidents = {2016: 14, 2019: 18, 2017: 13, 2018: 16, 2014: 8, 2015: 10}
best_key = None
for key in incidents:
    if best_key == None or incidents[best_key] < incidents[key]:
        best_key = key
print("Year", best_key, "had", incidents[best_key], "incidents (the max)")
# Out:
# Year 2019 had 18 incidents (the max)
